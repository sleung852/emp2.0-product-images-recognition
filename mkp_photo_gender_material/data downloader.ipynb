# %%
import pandas as pd
from tqdm import tqdm
import os
from urllib.request import urlretrieve

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'data downloader.ipynb',
#  'data.zip',
#  'New folder',
#  'test_v3.csv',
#  'train_v3.csv',
#  'Untitled.ipynb']

# %%
gar=pd.read_excel('gar.xlsx')
elec=pd.read_excel('elec.xlsx')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-8-269450ae2780> in <module>
# ----> 1 gar=pd.read_excel('gar.xlsx')
#       2 elec=pd.read_excel('elec.xlsx')
#
# ~\AppData\Roaming\Python\Python36\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     176                 else:
#     177                     kwargs[new_arg_name] = new_arg_value
# --> 178             return func(*args, **kwargs)
#     179         return wrapper
#     180     return _deprecate_kwarg
#
# ~\AppData\Roaming\Python\Python36\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     176                 else:
#     177                     kwargs[new_arg_name] = new_arg_value
# --> 178             return func(*args, **kwargs)
#     179         return wrapper
#     180     return _deprecate_kwarg
#
# ...

# %%
dataset=train.append(test)

# %%
url='http://i03.hktdc-img.com/rsc?profile=productimage&subprofile=enlarge&pid={}&file=image_1.jpg'.format(img_id)

# %%
dataset=dataset.loc[:,'RID':]
dataset
# Out:
#           RID  CATEGORY_ID  CATEGORY_DEPTH                       ROOT  \
# 0       17403           22               3  Automobiles & Motorcycles
# 1      118022          176               4  Automobiles & Motorcycles
# 2      120118          173               4  Automobiles & Motorcycles
# 3      121049          232               3               Baby Product
# 4      121110          232               3               Baby Product
# 5      123744          234               3               Baby Product
# 6      123754          234               3               Baby Product
# 7      123764          234               3               Baby Product
# 8      123773          234               3               Baby Product
# 9      124596          234               3               Baby Product
# 10     124606          234               3               Baby Product
# 11     124670          234               3               Baby Product
# ...

# %%
print('Initiating downloading images...')
for _,row in tqdm(dataset.iterrows(), total=dataset.shape[0]):
    urlretrieve(row['IMAGE_URL'], os.path.join('data','{}.jpg'.format(row['PRODUCT_ID'])))
print('Image downloading completed!')
# Out:
# Initiating downloading images...
# 100%|████████████████████████████████| 165995/165995 [5:27:50<00:00,  8.15it/s]
# Image downloading completed!

# %%
import boto3
s3 = boto3.client('s3')
file = 'data.zip'
bucket='see-ml-storage'

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'data downloader.ipynb',
#  'data.zip',
#  'New folder',
#  'test_v3.csv',
#  'train_v3.csv']

# %%
s3.upload_file(file, bucket, file)
